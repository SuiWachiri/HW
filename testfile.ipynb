# %%
import pandas as pd

# %%
data = pd.read_csv('Energy_and_Water_Use_-_Municipal_Buildings.csv')

# %%
data.iloc[:,[0,8,7,13]][(data['water_use_all_water_sources_kgal']==data.water_use_all_water_sources_kgal.idxmax()) |
                       (data['water_use_all_water_sources_kgal'] ==data.water_use_all_water_sources_kgal.max()) ]
# Out:
#      cartodb_id                      property_name   department  \
# 199         200  Sanitation: 21/32  Gaffey St Yard  Sanitation:
#
#      water_use_all_water_sources_kgal
# 199                           20040.1

# %%
data['department'].groupby(data['department']).describe()
# Out:
#             count unique          top freq
# department
# Animal         14      1       Animal   14
# CDD:            2      1         CDD:    2
# Cultural        6      1     Cultural    6
# DOT:           13      1         DOT:   13
# Fire          135      1         Fire  135
# GSD            14      1          GSD   14
# ITA:            2      1         ITA:    2
# Libraries:    143      1   Libraries:  143
# Municipal      45      1    Municipal   45
# Municipal:      2      1   Municipal:    2
# Personnel       4      1    Personnel    4
# Police         60      1       Police   60
# Public          2      1       Public    2
# Residence:      2      1   Residence:    2
# Sanitation:    13      1  Sanitation:   13
# Street         11      1       Street   11

# %%
data.iloc[:,[1,8,7,12]].sort_values('total_ghg_emissions_metric_tons_co2e',ascending=0)[(data['total_ghg_emissions_metric_tons_co2e'] ==  data['total_ghg_emissions_metric_tons_co2e'])].head()
# Out:
# C:\Users\Sui\AppData\Local\conda\conda\envs\rstudio\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                                               the_geom  \
# 4    0101000020E610000063416150A68F5DC01903EB387E06...
# 5    0101000020E61000002A8E03AF968F5DC079AC1919E406...
# 244  0101000020E61000008B4F01309E8F5DC0B69E211CB306...
# 0    0101000020E61000008B4F01309E8F5DC0B69E211CB306...
# 14   0101000020E6100000A6EF3504C78E5DC0DE5A26C3F106...
#
#                                          property_name department  \
# 4                      Municipal: 1/14  City Hall East  Municipal
# 5               Municipal: 1/2   Los Angeles City Hall  Municipal
# 244  Police Department: 9/63   Police Administratio...     Police
# 0    Police Department: 9/63   Police Administratio...     Police
# 14                         Municipal: 1/18  Piper Tech  Municipal
#
# ...

# %%
data.iloc[:,[0,7,8,3]][(data['energy_star_score '] >=75)].sort_values(by='energy_star_score ',ascending=0)
# Out:
#      cartodb_id  department  \
# 238         239   Personnel
# 241         242         GSD
# 464         465   Personnel
# 248         249   Municipal
# 217         218   Municipal
# 440         441   Municipal
# 436         437   Municipal
# 445         446   Municipal
# 247         248      Public
# 3             4      Public
# 212         213   Municipal
# 207         208   Municipal
# 442         443   Municipal
# 214         215  Municipal:
#
#                                          property_name  energy_star_score
# 238  Personnel Department:  Personnel Medical Svc D...                 100
# 241  GSD Facilities: 7th street shops, yards, offic...                 100
# 464  Personnel Department:  Personnel Medical Svc D...                 100
# 248                      Municipal: 1/44  Fig Plaza II                  96
# 217           Municipal: 1/4  Sunland Tujnga Municipal                  91
# 440              Municipal: 1/99  Wilmington Municipal                  91
# ...

# %%
data.groupby(['year_ending'])['water_use_all_water_sources_kgal'].max()
# Out:
# year_ending
# 31-Dec-14    20040.1
# 31-Dec-15    12601.7
# Name: water_use_all_water_sources_kgal, dtype: float64

# %%
df1 = pd.DataFrame(data, columns = ['weather_normalized_site_eui_kbtu_ft','weather_normalized_source_eui_kbtu_ft'])
df2 = pd.DataFrame(data, columns = ['weather_normalized_site_eui_kbtu_ft','weather_normalized_source_eui_kbtu_ft'])

EffTrans = data.concat([df1, df2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-42417d929606> in <module>()
#       2 df2 = pd.DataFrame(data, columns = ['weather_normalized_site_eui_kbtu_ft','weather_normalized_source_eui_kbtu_ft'])
#       3
# ----> 4 EffTrans = data.concat([df1, df2])
#
# ~\AppData\Local\conda\conda\envs\rstudio\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
data['EffTrans'] = data['weather_normalized_site_eui_kbtu_ft']/data['weather_normalized_source_eui_kbtu_ft']
data.iloc[:,[0,7,8,15,14,19]][(data['weather_normalized_site_eui_kbtu_ft'] >0)]
# Out:
#      cartodb_id   department  \
# 0             1       Police
# 1             2    Municipal
# 2             3    Municipal
# 4             5    Municipal
# 5             6    Municipal
# 7             8       Police
# 9            10       Police
# 10           11         ITA:
# 11           12       Police
# 12           13   Libraries:
# 15           16       Police
# 17           18         Fire
# 18           19         Fire
# 20           21         Fire
# 21           22         Fire
# 22           23         Fire
# 23           24         Fire
# 24           25         Fire
# 25           26         Fire
# 26           27         Fire
# 27           28         Fire
# 28           29         Fire
# 29           30         Fire
# 30           31         Fire
# 31           32         Fire
# 33           34         Fire
# 34           35         Fire
# 35           36         Fire
# 36           37         Fire
# 38           39         Fire
# ..          ...          ...
# ...
